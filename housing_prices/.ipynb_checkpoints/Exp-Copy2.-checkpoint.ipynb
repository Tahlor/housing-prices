# %%
model_variables = ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'LandContour_Low_orig_categ', 'BsmtUnfSF_cont_trans_normal', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'TotalSQF_cont_trans_normal', 'Heating_Wall_orig_categ', 'LotShape_Reg_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_Mitchel_orig_categ', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'Exterior1st_CemntBd_orig_categ', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'Heating_GasA_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofStyle_Gable_orig_categ', 'SaleCondition_Partial_orig_categ', 'Neighborhood_ClearCr_orig_categ', 'Foundation_Stone_orig_categ', 'RoofMatl_Membran_orig_categ', 'RoofMatl_Metal_orig_categ', 'MSSubClass_70_orig_categ', 'Functional_ord_trans_scale01', 'YrSold_2008_orig_categ', 'Neighborhood_CollgCr_orig_categ', 'LandContour_HLS_orig_categ', 'MiscVal_cont_trans_root', 'Fence_ord_trans_quadratic', 'Neighborhood_NPkVill_orig_categ', 'PoolQC_ord_trans_quadratic', '1stFlrSF_cont_trans_quadratic', 'LotConfig_FR3_orig_categ', 'BsmtQual_ord_trans_scale01', 'SaleCondition_Alloca_orig_categ', 'NewHouse_orig_categ', 'LotShape_IR1_orig_categ', 'Exterior2nd_AsbShng_orig_categ', 'Id', 'MSSubClass_20_orig_categ', 'Exterior2nd_HdBoard_orig_categ', 'ExterCond_ord_trans_scale01', 'HouseStyle_2Story_orig_categ', 'Exterior2nd_Brk Cmn_orig_categ', 'RoofStyle_Shed_orig_categ', 'FullBath_cont_trans_quadratic', 'HouseStyle_2.5Unf_orig_categ', 'Alley_Pave_orig_categ', 'RoofMatl_Tar&Grv_orig_categ', 'Exterior1st_CBlock_orig_categ', 'LotConfig_FR2_orig_categ', 'RoofStyle_Mansard_orig_categ', 'PoolArea_cont_trans_root', 'Condition2_RRAe_orig_categ', 'LandSlope_Gtl_orig_categ', 'MiscFeature_Othr_orig_categ', 'MSSubClass_80_orig_categ', 'Fireplaces_cont_trans_normal', 'RoofStyle_Hip_orig_categ', 'Exterior1st_WdShing_orig_categ', 'Condition2_Feedr_orig_categ', 'MiscFeature_Shed_orig_categ', 'Neighborhood_Blmngtn_orig_categ', 'RoofMatl_WdShngl_orig_categ', 'Electrical_SBrkr_orig_categ', 'Exterior1st_Wd Sdng_orig_categ', 'BldgType_Twnhs_orig_categ', 'MSSubClass_45_orig_categ', 'BsmtFinSF1_cont_trans_normal', 'EnclosedPorch_cont_trans_quadratic', 'LotConfig_Corner_orig_categ', 'GarageType_CarPort_orig_categ', 'KitchenQual_ord_trans_scale01', 'SaleType_ConLI_orig_categ', 'Foundation_BrkTil_orig_categ', 'Foundation_PConc_orig_categ', 'Exterior2nd_Stucco_orig_categ', 'PrchSQ_cont_trans_quadratic', 'Exterior1st_Plywood_orig_categ', 'GarageType_0_orig_categ', 'MiscFeature_Gar2_orig_categ', 'BsmtFinType2_ord_trans_quadratic', 'Heating_GasW_orig_categ', 'SaleType_Oth_orig_categ', 'LotShape_IR3_orig_categ', 'Exterior2nd_VinylSd_orig_categ', 'SaleType_CWD_orig_categ', 'HouseStyle_SLvl_orig_categ', 'Exterior1st_Stucco_orig_categ', 'Condition2_Norm_orig_categ', 'Neighborhood_SWISU_orig_categ', 'MSSubClass_85_orig_categ', 'BldgType_TwnhsE_orig_categ', 'BldgType_Duplex_orig_categ', 'WoodDeckSF_cont_trans_scale01', 'GarageType_Attchd_orig_categ', 'MSSubClass_40_orig_categ', 'GarageAgeInv_cont_trans_normal', 'BsmtHalfBath_cont_trans_normal', 'Neighborhood_StoneBr_orig_categ', 'GarageType_Basment_orig_categ', 'MasVnrType_ord_trans_root', 'LandSlope_Mod_orig_categ', 'Condition1_RRNn_orig_categ', 'BsmtFinSF2_cont_trans_quadratic', 'Condition1_RRAn_orig_categ', 'MSSubClass_160_orig_categ', 'Neighborhood_SawyerW_orig_categ', 'RoofMatl_CompShg_orig_categ', 'Exterior1st_AsbShng_orig_categ', 'Condition2_RRAn_orig_categ', 'Exterior1st_HdBoard_orig_categ', 'LandSlope_Sev_orig_categ', 'MSSubClass_90_orig_categ', 'Neighborhood_Timber_orig_categ', 'Season_0_orig_categ', 'Exterior2nd_Wd Shng_orig_categ', 'Utilities_ord_trans_quadratic', 'OpenPorchSF_cont_trans_normal', 'Exterior2nd_Stone_orig_categ', 'MSSubClass_75_orig_categ', 'Exterior1st_AsphShn_orig_categ', 'MoSold_cont_trans_normal', 'Season_2_orig_categ', 'Heating_Grav_orig_categ', 'Electrical_FuseA_orig_categ', 'LowQualFinSF_cont_trans_root', 'KitchenAbvGr_cont_trans_root', 'Neighborhood_Somerst_orig_categ']

# %%
import os
print(os.getcwd())
import pandas as pd
def extract_main_dataset(path=None):
	if path is None:
		#path = r'/medic/github/housing-prices/data/train.csv'
		path = r'/medic/github/housing-prices/output/processed_features.csv'
	df = pd.read_csv(path)
	y = df["SalePrice"].values
	x = df.drop(["SalePrice"], axis=1).values
	return (x, y)
# Out:
# /medic/github/housing-prices/housing_prices

# %%
from transforms import transform
import pandas as pd
from main import get_test_score
import main
import random
import prep_features
from main import get_test_score
import warnings
import numpy as np
import model
import prep_features
import import_data
import warnings

def reimport():
    # %load_ext autoreload
    # %autoreload 2
    warnings.filterwarnings('ignore')
    path_test = r'../data/test_data3.csv'
    #path_test = r'../data/all_data.csv'
    path_training = r'../data/train.csv'

    raw_training = import_data.process_data(path_training)
    test_df = import_data.process_data(path_test)
    training_df = raw_training
    p_features, targets, p_test_features, test_targets = prep_features.main(training_df, test_df, drop_outliers=False, use_log=True)

    targets = targets.drop(["SalePriceMiscVal"], axis=1)
    test_targets = test_targets.drop(["SalePriceMiscVal"], axis=1)

    targets = targets["SalePrice"]
    test_targets = test_targets["SalePrice"]
    IGNORE=["Id"]
    features = p_features
    test_features=p_test_features
    globals().update(locals())

    
reimport()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done recoding
# {'GarageQual': 'ordinal', 'BsmtExposure': 'ordinal', 'PoolQC': 'ordinal', 'BsmtCond': 'ordinal', 'ExterQual': 'ordinal', 'BsmtFinType2': 'ordinal', 'Fence': 'ordinal', 'HeatingQC': 'ordinal', 'BsmtFinType1': 'ordinal', 'MasVnrType': 'ordinal', 'Functional': 'ordinal', 'GarageCond': 'ordinal', 'PavedDrive': 'ordinal', 'ExterCond': 'ordinal', 'CentralAir': 'ordinal', 'Utilities': 'ordinal', 'GarageFinish': 'ordinal', 'FireplaceQu': 'ordinal', 'KitchenQual': 'ordinal', 'BsmtQual': 'ordinal'}
# Done creating new features
# Done standardizing features
# [MICE] Completing matrix with shape (1460, 1)
# [MICE] Starting imputation round 1/110, elapsed time 0.000
# [MICE] Starting imputation round 2/110, elapsed time 0.001
# [MICE] Starting imputation round 3/110, elapsed time 0.001
# [MICE] Starting imputation round 4/110, elapsed time 0.001
# [MICE] Starting imputation round 5/110, elapsed time 0.002
# [MICE] Starting imputation round 6/110, elapsed time 0.002
# [MICE] Starting imputation round 7/110, elapsed time 0.002
# [MICE] Starting imputation round 8/110, elapsed time 0.002
# [MICE] Starting imputation round 9/110, elapsed time 0.003
# [MICE] Starting imputation round 10/110, elapsed time 0.003
# [MICE] Starting imputation round 11/110, elapsed time 0.003
# [MICE] Starting imputation round 12/110, elapsed time 0.003
# [MICE] Starting imputation round 13/110, elapsed time 0.004
# [MICE] Starting imputation round 14/110, elapsed time 0.004
# [MICE] Starting imputation round 15/110, elapsed time 0.004
# [MICE] Starting imputation round 16/110, elapsed time 0.004
# [MICE] Starting imputation round 17/110, elapsed time 0.005
# [MICE] Starting imputation round 18/110, elapsed time 0.005
# [MICE] Starting imputation round 19/110, elapsed time 0.005
# [MICE] Starting imputation round 20/110, elapsed time 0.005
# [MICE] Starting imputation round 21/110, elapsed time 0.006
# [MICE] Starting imputation round 76/110, elapsed time 0.021
# [MICE] Starting imputation round 77/110, elapsed time 0.021
# [MICE] Starting imputation round 78/110, elapsed time 0.022
# [MICE] Starting imputation round 79/110, elapsed time 0.022
# [MICE] Starting imputation round 80/110, elapsed time 0.022
# [MICE] Starting imputation round 81/110, elapsed time 0.022
# [MICE] Starting imputation round 82/110, elapsed time 0.023
# [MICE] Starting imputation round 83/110, elapsed time 0.023
# [MICE] Starting imputation round 84/110, elapsed time 0.023
# [MICE] Starting imputation round 85/110, elapsed time 0.023
# [MICE] Starting imputation round 86/110, elapsed time 0.024
# [MICE] Starting imputation round 87/110, elapsed time 0.024
# [MICE] Starting imputation round 88/110, elapsed time 0.024
# [MICE] Starting imputation round 89/110, elapsed time 0.025
# [MICE] Starting imputation round 90/110, elapsed time 0.025
# [MICE] Starting imputation round 91/110, elapsed time 0.025
# [MICE] Starting imputation round 92/110, elapsed time 0.025
# [MICE] Starting imputation round 93/110, elapsed time 0.026
# [MICE] Starting imputation round 94/110, elapsed time 0.026
# [MICE] Starting imputation round 95/110, elapsed time 0.026
# [MICE] Starting imputation round 96/110, elapsed time 0.026
# [MICE] Starting imputation round 97/110, elapsed time 0.027
# [MICE] Starting imputation round 98/110, elapsed time 0.027
# [MICE] Starting imputation round 99/110, elapsed time 0.027
# [MICE] Starting imputation round 100/110, elapsed time 0.027
# [MICE] Starting imputation round 101/110, elapsed time 0.028
# [MICE] Starting imputation round 102/110, elapsed time 0.028
# [MICE] Starting imputation round 103/110, elapsed time 0.028
# [MICE] Starting imputation round 104/110, elapsed time 0.029
# [MICE] Starting imputation round 105/110, elapsed time 0.029
# [MICE] Starting imputation round 106/110, elapsed time 0.029
# [MICE] Starting imputation round 107/110, elapsed time 0.029
# [MICE] Starting imputation round 108/110, elapsed time 0.030
# [MICE] Starting imputation round 109/110, elapsed time 0.030
# [MICE] Starting imputation round 110/110, elapsed time 0.030
# Done imputing variables
# Done creating dummies
# Done excluding vacuous variables

# %%
# %load_ext autoreload
# %autoreload 2
import main
MODEL_TYPE = "GradientBoosting"
import tools
def run(keep_list, model="ElasticNet", reduce_features=False, feats=None, test_feats=None):
    if feats is None:
        feats=features
    if test_feats is None:
        test_feats=test_features
    if not "Id" in keep_list:
        keep_list.append("Id")
    tr_f = feats[keep_list]
    ts_f = test_feats[keep_list]
    if reduce_features:
        keep_features = main.feature_reduction(tr_f, targets)
        ts_f = ts_f[keep_features]
        tr_f = tr_f[keep_features]
    my_model = main.create_model(tr_f, targets, ignore_features= IGNORE, type=model, X_validation=ts_f, y_validation=test_targets) # Lasso


    if model not in ["NN"]:
        #main.cv(my_model, tr_f, targets)
        my_model.model.fit(tr_f.drop(IGNORE,1), targets)
    else:
        pass

    #rmse_cv(my_model, features, targets)
    test_score = get_test_score(my_model, ts_f, test_targets)
    feature_importances = main.plot_features(my_model, tr_f)
    return test_score, feature_importances, my_model
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
import main
from random import shuffle

## Find the best transform of every feature

import prep_features
MODEL = "ElasticNet"
master_list = prep_features.get_features(features, "orig", inverse=False) # extended variables have a __ in them

# Run with all normalized values
# Take the most important feature - find best transform - use that
#["TotalSQF_normal", "OverallQual_normal", "LotArea_normal"]
keyword = "Garage"


# Check if variable is dropped from model, ignore in this case
# Dynamically update model

best_vars = []
#master_keep_list = prep_features.get_features(features, "_log") +  prep_features.get_features(features, "_categ") # keep only log variables
best_score = 1
while True:
    shuffle(master_list)
    
    # Use our best set of variables
    if 'best_keep_list' in globals():
        master_keep_list = best_keep_list[:]
    for keyword in master_list:
        keyword = keyword.replace("_orig", "")
        keep_list = [x for x in master_keep_list if keyword not in x]   # remove the variables we're testing
        try_list = prep_features.get_features(features, keyword) # get variables to try
        scores = []
        feature_importances_dict = {}
        if len(try_list) > 1:
            for new_var in try_list:
                score, feature_importance, _ = run(keep_list+[new_var], model=MODEL, reduce_features=False)
                feature_importances_dict[new_var]={"score":score, "feature_importances_dict":feature_importance}

                features_kept = list(zip(*feature_importance))[1]
                if new_var in features_kept:
                    scores.append((score, new_var, features_kept))

            # Only update if at least one variable was used and was good etc.
            if len(scores)>0:
                print("Updating master list!")
                scores.sort()
                best_score_of_group = scores[0][0]
                if best_score_of_group < best_score:
                    best_score = best_score_of_group
                    best_keep_list = master_keep_list[:]
                best_var = scores[0][1]
                best_vars.append(best_var)
                master_used_list = scores[0][2]
                if False:
                    master_keep_list = keep_list[:] + [best_var]
                else:
                    master_keep_list = list(master_used_list)[:]
        # Update master keep list

    # PRINT BEST MODEL
    print("Best model")
    score, feature_importance, best_model = run(master_keep_list)
    feature_list = [x[1] for x in feature_importance]
    print(set(feature_list))

    #for score in scores:
    #    print(score)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-aee807f1388d> in <module>()
#      33     for keyword in master_list:
#      34         keyword = keyword.replace("_orig", "")
# ---> 35         keep_list = [x for x in master_keep_list if keyword not in x]   # remove the variables we're testing
#      36         try_list = prep_features.get_features(features, keyword) # get variables to try
#      37         scores = []
#
# NameError: name 'master_keep_list' is not defined

# %%
reimport()
# Create model variable repository
#main_variables = prep_features.get_features(features, "_log") + regression_list[:] # anything in the regression + log

score, feature_importance, _ = run(p_features.columns, model="ElasticNetCV", reduce_features=False)
used_variables = list(list(zip(*feature_importance))[1]) # change model variables to the ones kept


main_variables = used_variables[:]

main_variables = list(set(main_variables))

main_var_df = pd.concat([features[main_variables], test_features[main_variables]], keys=["train","test"], axis=0)

# Why are there duplicates?
main_var_df = main_var_df.loc[:, ~main_var_df.columns.duplicated()]


bools = main_var_df.select_dtypes(include=["bool", "category"]).columns
main_var_df[bools] = main_var_df[bools].astype('int')
                         
log_features =main_var_df[prep_features.get_features(main_var_df, "_log")]
unlog_features =main_var_df[prep_features.get_features(main_var_df, "_log", inverse=True)]

# Create interactions
additive, _ = transform(log_features, rename=True, replace=True, trans_type="add")
subtractive, _ = transform(log_features, rename=True, replace=True, trans_type="subtract")
multiplicative, _ = transform(unlog_features, rename=True, replace=True, trans_type="multiply")
divisive,_ = transform(unlog_features, rename=True, replace=True, trans_type="divide")

temp = pd.concat([main_var_df, additive, subtractive, multiplicative, divisive],1)
#temp = pd.concat([main_var_df, multiplicative, divisive],1)
huge_variable_repository = pd.concat([temp.xs("train").reset_index(), p_features],1)
huge_variable_repository_test = pd.concat([temp.xs("test").reset_index(), p_test_features],1)
features = huge_variable_repository
test_features = huge_variable_repository_test
del temp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done recoding
# {'GarageQual': 'ordinal', 'BsmtExposure': 'ordinal', 'PoolQC': 'ordinal', 'BsmtCond': 'ordinal', 'ExterQual': 'ordinal', 'BsmtFinType2': 'ordinal', 'Fence': 'ordinal', 'HeatingQC': 'ordinal', 'BsmtFinType1': 'ordinal', 'MasVnrType': 'ordinal', 'Functional': 'ordinal', 'GarageCond': 'ordinal', 'PavedDrive': 'ordinal', 'ExterCond': 'ordinal', 'CentralAir': 'ordinal', 'Utilities': 'ordinal', 'GarageFinish': 'ordinal', 'FireplaceQu': 'ordinal', 'KitchenQual': 'ordinal', 'BsmtQual': 'ordinal'}
# Done creating new features
# Done standardizing features
# [MICE] Completing matrix with shape (1460, 1)
# [MICE] Starting imputation round 1/110, elapsed time 0.000
# [MICE] Starting imputation round 2/110, elapsed time 0.001
# [MICE] Starting imputation round 3/110, elapsed time 0.001
# [MICE] Starting imputation round 4/110, elapsed time 0.002
# [MICE] Starting imputation round 5/110, elapsed time 0.002
# [MICE] Starting imputation round 6/110, elapsed time 0.002
# [MICE] Starting imputation round 7/110, elapsed time 0.002
# [MICE] Starting imputation round 8/110, elapsed time 0.003
# [MICE] Starting imputation round 9/110, elapsed time 0.003
# [MICE] Starting imputation round 10/110, elapsed time 0.003
# [MICE] Starting imputation round 11/110, elapsed time 0.003
# [MICE] Starting imputation round 12/110, elapsed time 0.004
# [MICE] Starting imputation round 13/110, elapsed time 0.004
# [MICE] Starting imputation round 14/110, elapsed time 0.005
# [MICE] Starting imputation round 15/110, elapsed time 0.005
# [MICE] Starting imputation round 16/110, elapsed time 0.005
# [MICE] Starting imputation round 17/110, elapsed time 0.006
# [MICE] Starting imputation round 18/110, elapsed time 0.006
# [MICE] Starting imputation round 19/110, elapsed time 0.006
# [MICE] Starting imputation round 20/110, elapsed time 0.007
# [MICE] Starting imputation round 21/110, elapsed time 0.007
# [MICE] Starting imputation round 22/110, elapsed time 0.008
# [MICE] Starting imputation round 23/110, elapsed time 0.008
# [MICE] Starting imputation round 24/110, elapsed time 0.009
# [MICE] Starting imputation round 25/110, elapsed time 0.009
# [MICE] Starting imputation round 26/110, elapsed time 0.009
# [MICE] Starting imputation round 27/110, elapsed time 0.010
# [MICE] Starting imputation round 28/110, elapsed time 0.010
# [MICE] Starting imputation round 29/110, elapsed time 0.011
# [MICE] Starting imputation round 30/110, elapsed time 0.011
# [MICE] Starting imputation round 31/110, elapsed time 0.011
# [MICE] Starting imputation round 32/110, elapsed time 0.012
# [MICE] Starting imputation round 33/110, elapsed time 0.012
# [MICE] Starting imputation round 34/110, elapsed time 0.012
# [MICE] Starting imputation round 35/110, elapsed time 0.013
# [MICE] Starting imputation round 36/110, elapsed time 0.013
# [MICE] Starting imputation round 91/110, elapsed time 0.025
# [MICE] Starting imputation round 92/110, elapsed time 0.025
# [MICE] Starting imputation round 93/110, elapsed time 0.026
# [MICE] Starting imputation round 94/110, elapsed time 0.026
# [MICE] Starting imputation round 95/110, elapsed time 0.026
# [MICE] Starting imputation round 96/110, elapsed time 0.026
# [MICE] Starting imputation round 97/110, elapsed time 0.027
# [MICE] Starting imputation round 98/110, elapsed time 0.027
# [MICE] Starting imputation round 99/110, elapsed time 0.027
# [MICE] Starting imputation round 100/110, elapsed time 0.027
# [MICE] Starting imputation round 101/110, elapsed time 0.028
# [MICE] Starting imputation round 102/110, elapsed time 0.028
# [MICE] Starting imputation round 103/110, elapsed time 0.028
# [MICE] Starting imputation round 104/110, elapsed time 0.028
# [MICE] Starting imputation round 105/110, elapsed time 0.029
# [MICE] Starting imputation round 106/110, elapsed time 0.029
# [MICE] Starting imputation round 107/110, elapsed time 0.029
# [MICE] Starting imputation round 108/110, elapsed time 0.029
# [MICE] Starting imputation round 109/110, elapsed time 0.030
# [MICE] Starting imputation round 110/110, elapsed time 0.030
# Done imputing variables
# Done creating dummies
# Done excluding vacuous variables
# Test score: 0.1296602161922177
# Created 15 variables for add
# Created 15 variables for subtract
# Created 5778 variables for multiply
# Created 2694 variables for divide

# %%
print(model_variables)
# Out:
# ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'BsmtUnfSF_cont_trans_normal', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'TotalSQF_cont_trans_normal', 'Heating_Wall_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofStyle_Gable_orig_categ', 'SaleCondition_Partial_orig_categ', 'Neighborhood_ClearCr_orig_categ', ...

# %%
## RANDOM ONE
#model_variables = ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'LandContour_Low_orig_categ', 'BsmtUnfSF_cont_trans_normal', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'TotalSQF_cont_trans_normal', 'Heating_Wall_orig_categ', 'LotShape_Reg_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_Mitchel_orig_categ', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'Exterior1st_CemntBd_orig_categ', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'Heating_GasA_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofStyle_Gable_orig_categ', 'SaleCondition_Partial_orig_categ', 'Neighborhood_ClearCr_orig_categ', 'Foundation_Stone_orig_categ', 'RoofMatl_Membran_orig_categ', 'RoofMatl_Metal_orig_categ', 'MSSubClass_70_orig_categ', 'Functional_ord_trans_scale01', 'YrSold_2008_orig_categ', 'Neighborhood_CollgCr_orig_categ', 'LandContour_HLS_orig_categ', 'MiscVal_cont_trans_root', 'Fence_ord_trans_quadratic', 'Neighborhood_NPkVill_orig_categ', 'PoolQC_ord_trans_quadratic', '1stFlrSF_cont_trans_quadratic', 'LotConfig_FR3_orig_categ', 'BsmtQual_ord_trans_scale01', 'SaleCondition_Alloca_orig_categ', 'NewHouse_orig_categ', 'LotShape_IR1_orig_categ', 'Exterior2nd_AsbShng_orig_categ', 'Id', 'MSSubClass_20_orig_categ', 'Exterior2nd_HdBoard_orig_categ', 'ExterCond_ord_trans_scale01', 'HouseStyle_2Story_orig_categ', 'Exterior2nd_Brk Cmn_orig_categ', 'RoofStyle_Shed_orig_categ', 'FullBath_cont_trans_quadratic', 'HouseStyle_2.5Unf_orig_categ', 'Alley_Pave_orig_categ', 'RoofMatl_Tar&Grv_orig_categ', 'Exterior1st_CBlock_orig_categ', 'LotConfig_FR2_orig_categ', 'RoofStyle_Mansard_orig_categ', 'PoolArea_cont_trans_root', 'Condition2_RRAe_orig_categ', 'LandSlope_Gtl_orig_categ', 'MiscFeature_Othr_orig_categ', 'MSSubClass_80_orig_categ', 'Fireplaces_cont_trans_normal', 'RoofStyle_Hip_orig_categ', 'Exterior1st_WdShing_orig_categ', 'Condition2_Feedr_orig_categ', 'MiscFeature_Shed_orig_categ', 'Neighborhood_Blmngtn_orig_categ', 'RoofMatl_WdShngl_orig_categ', 'Electrical_SBrkr_orig_categ', 'Exterior1st_Wd Sdng_orig_categ', 'BldgType_Twnhs_orig_categ', 'MSSubClass_45_orig_categ', 'BsmtFinSF1_cont_trans_normal', 'EnclosedPorch_cont_trans_quadratic', 'LotConfig_Corner_orig_categ', 'GarageType_CarPort_orig_categ', 'KitchenQual_ord_trans_scale01', 'SaleType_ConLI_orig_categ', 'Foundation_BrkTil_orig_categ', 'Foundation_PConc_orig_categ', 'Exterior2nd_Stucco_orig_categ', 'PrchSQ_cont_trans_quadratic', 'Exterior1st_Plywood_orig_categ', 'GarageType_0_orig_categ', 'MiscFeature_Gar2_orig_categ', 'BsmtFinType2_ord_trans_quadratic', 'Heating_GasW_orig_categ', 'SaleType_Oth_orig_categ', 'LotShape_IR3_orig_categ', 'Exterior2nd_VinylSd_orig_categ', 'SaleType_CWD_orig_categ', 'HouseStyle_SLvl_orig_categ', 'Exterior1st_Stucco_orig_categ', 'Condition2_Norm_orig_categ', 'Neighborhood_SWISU_orig_categ', 'MSSubClass_85_orig_categ', 'BldgType_TwnhsE_orig_categ', 'BldgType_Duplex_orig_categ', 'WoodDeckSF_cont_trans_scale01', 'GarageType_Attchd_orig_categ', 'MSSubClass_40_orig_categ', 'GarageAgeInv_cont_trans_normal', 'BsmtHalfBath_cont_trans_normal', 'Neighborhood_StoneBr_orig_categ', 'GarageType_Basment_orig_categ', 'MasVnrType_ord_trans_root', 'LandSlope_Mod_orig_categ', 'Condition1_RRNn_orig_categ', 'BsmtFinSF2_cont_trans_quadratic', 'Condition1_RRAn_orig_categ', 'MSSubClass_160_orig_categ', 'Neighborhood_SawyerW_orig_categ', 'RoofMatl_CompShg_orig_categ', 'Exterior1st_AsbShng_orig_categ', 'Condition2_RRAn_orig_categ', 'Exterior1st_HdBoard_orig_categ', 'LandSlope_Sev_orig_categ', 'MSSubClass_90_orig_categ', 'Neighborhood_Timber_orig_categ', 'Season_0_orig_categ', 'Exterior2nd_Wd Shng_orig_categ', 'Utilities_ord_trans_quadratic', 'OpenPorchSF_cont_trans_normal', 'Exterior2nd_Stone_orig_categ', 'MSSubClass_75_orig_categ', 'Exterior1st_AsphShn_orig_categ', 'MoSold_cont_trans_normal', 'Season_2_orig_categ', 'Heating_Grav_orig_categ', 'Electrical_FuseA_orig_categ', 'LowQualFinSF_cont_trans_root', 'KitchenAbvGr_cont_trans_root', 'Neighborhood_Somerst_orig_categ']
warnings.filterwarnings('ignore')
#model_variables = used_variables[:]
#model_variables =list(p_features.columns)

# %load_ext autoreload
# %autoreload 2
## Check if adding variable helps model
MODEL = "ElasticNetCV"

# Baseline
score, feature_importance, _ = run(model_variables, model="ElasticNetCV", reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
best_score = score
used_variables = list(list(zip(*feature_importance))[1]) # change model variables to the ones kept
variable_repository = list(huge_variable_repository.columns)

scores = []
while True:
    r = random.randint(0,len(variable_repository)-1)
    next_var = variable_repository[r]
    t= huge_variable_repository[model_variables+[next_var]]
    #tools.print_null(t)
    score, feature_importance, _ = run(model_variables+[next_var], model=MODEL, reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
    cv_score = main.cv(my_model, huge_variable_repository[model_variables+[next_var]], targets)
    score=(score+cv_score)/2
    
    features_kept = list(zip(*feature_importance))[1]
    scores.append(score)
    if next_var in features_kept and score+.0001<best_score:
        print("Updating master list! Adding {}".format(next_var))
        model_variables = model_variables+[next_var]
        #list(features_kept)
        best_score=score
    if len(scores)>100:
        scores = scores[-100:]
    best_score=np.min(scores)

    r2 = random.randint(0,len(model_variables)-1)
    remove_var = model_variables[r2]
    score, feature_importance, _ = run([v for v in model_variables if v != remove_var], model=MODEL, reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
    cv_score = main.cv(my_model, huge_variable_repository[model_variables+[next_var]], targets)
    score=(score+cv_score)/2
    scores.append(score)
    if score+.0001<best_score:
        print("Updating master list! Removing {}".format(remove_var))
        model_variables.remove(remove_var)
        #list(features_kept)
    if len(scores)>100:
        scores = scores[-100:]
    best_score=np.min(scores)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Test score: 0.11255633481266816
# Test score: 0.11259067809181263
# CV score: 0.11360667161545071
# Test score: 0.11255624532783781
# CV score: 0.11360667161545071
# Test score: 0.11259304737111112
# CV score: 0.11364120331434516
# Test score: 0.11255615540714645
# CV score: 0.11364120331434516
# Test score: 0.11268776511570709
# CV score: 0.11332588111981097
# Test score: 0.11255633449561891
# CV score: 0.11332588111981097
# Test score: 0.11256245733528807
# CV score: 0.1137954154961824
# Test score: 0.11255147893361674
# CV score: 0.1137954154961824
# Test score: 0.11256363919893089
# CV score: 0.1136421717100271
# Test score: 0.11260256893904529
# CV score: 0.1136421717100271
# Test score: 0.11270018996289956
# CV score: 0.11365743180028016
# Test score: 0.1131211177963379
# CV score: 0.11365743180028016
# Test score: 0.1126215408081504
# CV score: 0.1159011275093171
# Test score: 0.11249855591762761
# CV score: 0.1159011275093171
# Test score: 0.11249088480555174
# CV score: 0.11354773221351444
# Test score: 0.1125423339087021
# CV score: 0.11354773221351444
# Test score: 0.11282479265550734
# CV score: 0.11341123209152884
# Test score: 0.11257382396754559
# CV score: 0.11341123209152884
# Test score: 0.11237423435302349
# CV score: 0.1135074246637866
# Test score: 0.11255548963777116
# CV score: 0.1135074246637866
# Test score: 0.11258110962975862
# CV score: 0.11357914391128862
# Test score: 0.11255662497065107
# CV score: 0.11357914391128862
# Test score: 0.11262031365977368
# CV score: 0.11295675223557453
# Test score: 0.23373768480308346
# CV score: 2.32899870909114
# Test score: 0.11263847164452095
# CV score: 2.32899870909114
# Test score: 0.1125970849005026
# CV score: 0.11346615198477332
# Test score: 0.11258653059850389
# CV score: 0.11346615198477332
# Test score: 0.11288912115280242
# CV score: 0.1132844830984677
# Test score: 0.11256568130355497
# CV score: 0.1132844830984677
# Test score: 0.11259694775425638
# CV score: 0.11311170397255825
# Test score: 0.11258653342468523
# CV score: 0.11311170397255825
# Test score: 0.11281441720988607
# CV score: 0.11330217355607339
# Test score: 0.11266345578100029
# CV score: 0.11330217355607339
# Test score: 0.11268400840163667
# CV score: 0.11295945734923614
# Test score: 0.11256568130355497
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-ac61c41d71cb> in <module>()
#      40     remove_var = model_variables[r2]
#      41     score, feature_importance, _ = run([v for v in model_variables if v != remove_var], model=MODEL, reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
# ---> 42     cv_score = main.cv(my_model, huge_variable_repository[model_variables+[next_var]], targets)
#      43     score=(score+cv_score)/2
#      44     scores.append(score)
#
# /medic/github/housing-prices/housing_prices/main.py in cv(model, features, targets)
#     184 def cv(model, features, targets):
#     185     scorer = make_scorer(rmsl_metric, greater_is_better=True)
# --> 186     cv_results = cross_validate(model.model, features.drop(model.ignore_features, axis=1), targets, return_train_score=False, cv=5, scoring=scorer)
#     187     score = np.mean(cv_results["test_score"])
#     188     print("CV score: {}".format(score))
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     204             fit_params, return_train_score=return_train_score,
#     205             return_times=True)
# --> 206         for train, test in cv.split(X, y, groups))
#     207
#     208     if return_train_score:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     456             estimator.fit(X_train, **fit_params)
#     457         else:
# --> 458             estimator.fit(X_train, y_train, **fit_params)
#     459
#     460     except Exception as e:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/linear_model/coordinate_descent.py in fit(self, X, y)
#    1132         else:
#    1133             X = check_array(X, 'csc', dtype=[np.float64, np.float32],
# -> 1134                             order='F', copy=copy_X)
#    1135             copy_X = False
#    1136
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# KeyboardInterrupt:

# %%
def drop_worst(n=100):
    vr = variable_repository[:]
    score_variables=[]
    while len(vr) > 300:
        print("Variables considered: {}".format(len(vr)))
        score, feature_importance, _ = run(variable_repository, model="GradientBoosting", reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
        score_variables.append((score,vr[:]))
        new_vr = [x for x in feature_importance if x[0]>0] # drop complete duds
        vr = new_vr[:-n]

drop_worst(100)
#cv_score = main.cv(my_model, features[model_variables], targets)
# Out:
# Variables considered: 9232
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-73224776336e> in <module>()
#       9         vr = new_vr[:-n]
#      10
# ---> 11 drop_worst(100)
#      12 #cv_score = main.cv(my_model, features[model_variables], targets)
#
# <ipython-input-150-73224776336e> in drop_worst(n)
#       4     while len(vr) > 300:
#       5         print("Variables considered: {}".format(len(vr)))
# ----> 6         score, feature_importance, _ = run(variable_repository, model="GradientBoosting", reduce_features=False, feats=huge_variable_repository, test_feats=huge_variable_repository_test)
#       7         score_variables.append((score,vr[:]))
#       8         new_vr = [x for x in feature_importance if x[0]>0] # drop complete duds
#
# <ipython-input-27-2345320c7c7e> in run(keep_list, model, reduce_features, feats, test_feats)
#      20     #tools.print_null(tr_f)
#      21     #print(tr_f["Heating_Floor_orig_categ"])
# ---> 22     my_model = main.create_model(tr_f, targets, ignore_features= IGNORE, type=model, X_validation=ts_f, y_validation=test_targets) # Lasso
#      23
#      24
#
# /medic/github/housing-prices/housing_prices/main.py in create_model(X_train, y_train, ignore_features, type, X_validation, y_validation, verbose)
#     240         learner.fit(X_train, y_train)
#     241     else:
# --> 242         learner.fit(X_train, y_train)
#     243     if type in ['Lasso', 'ElasticNet']:
#     244         coef = pd.Series(learner.coef_, index=X_train.columns)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/gradient_boosting.py in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/gradient_boosting.py in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# /usr/local/lib/python3.5/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /usr/local/lib/python3.5/dist-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
print(huge_variable_repository.columns)
# Out:
# Index(['index', 'LotArea_cont_trans_root', 'BsmtQual_ord_trans_quadratic',
#        'Neighborhood_Crawfor_orig_categ', '1stFlrSF_cont_trans_quadratic',
#        'LargeHouse_orig_categ', 'BsmtFinSF2_cont_trans_quadratic',
#        'GarageQual_ord_trans_quadratic', 'MasVnrType_ord_trans_quadratic',
#        'EnclosedPorch_cont_trans_quadratic',
#        ...
#        'Neighborhood_Crawfor_orig_categ', 'LandSlope_Sev_orig_categ',
#        'SaleType_Oth_orig_categ', 'Neighborhood_ClearCr_orig_categ',
#        'RoofStyle_Hip_orig_categ', 'Exterior1st_AsphShn_orig_categ',
#        'Exterior2nd_BrkFace_orig_categ', 'Neighborhood_BrDale_orig_categ',
#        'SaleType_New_orig_categ', 'Street_Grvl_orig_categ'],
#       dtype='object', length=9112)

# %%
print(p_features.columns)
# Out:
# Index(['Id', 'TotalSQF_cont_trans_log', 'BedroomAbvGr_cont_trans_log',
#        'GarageArea_cont_trans_log', '3SsnPorch_cont_trans_log',
#        'BsmtFinSF1_cont_trans_log', 'HouseAge_cont_trans_log',
#        'TotalBsmtSF_cont_trans_log', 'MiscVal_cont_trans_log',
#        'LotFrontage_cont_trans_log',
#        ...
#        'Neighborhood_Crawfor_orig_categ', 'LandSlope_Sev_orig_categ',
#        'SaleType_Oth_orig_categ', 'Neighborhood_ClearCr_orig_categ',
#        'RoofStyle_Hip_orig_categ', 'Exterior1st_AsphShn_orig_categ',
#        'Exterior2nd_BrkFace_orig_categ', 'Neighborhood_BrDale_orig_categ',
#        'SaleType_New_orig_categ', 'Street_Grvl_orig_categ'],
#       dtype='object', length=617)

# %%
#x = huge_variable_repository["BsmtFinType1_ord_trans_quadratic_divide_Condition1_RRAe_categ_trans_divide"]
#print(np.isinf(x).any())
print(r2)
print(model_variables)
# Out:
# 176
# ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'BsmtUnfSF_cont_trans_normal', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'TotalSQF_cont_trans_normal', 'Heating_Wall_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofStyle_Gable_orig_categ', 'SaleCondition_Partial_orig_categ', 'Neighborhood_ClearCr_orig_categ', ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2
import main
## Check if adding variable helps model

import prep_features
MODEL = "ElasticNet"

# Baseline
score, feature_importance, _ = run(model_variables, model="ElasticNet", reduce_features=False)
best_score = score
used_variables = list(list(zip(*feature_importance))[1]) # change model variables to the ones kept

#model_variables = regression_list[:]
variable_repository = list(features.columns.values[:])+huge_variable_repository
shuffle(variable_repository)
#print(variable_repository)

#get_features(features, "_orig")

# print(len(model_variables))
# score, feature_importance, _ = run(model_variables, model="ElasticNet", reduce_features=False)
scores = []
while True:
    for next_var in variable_repository:
        score, feature_importance, _ = run(model_variables+[next_var], model=MODEL, reduce_features=False)
        #features_kept = list(zip(*feature_importance))[1]
        scores.append(score)
        if next_var in features_kept and score+.0001<best_score:
            print("Updating master list!")
            model_variables = model_variables+[next_var]
            #list(features_kept)
            best_score=score
        if len(scores)>100:
            scores = scores[-100:]
        best_score=np.min(scores)

    shuffle(model_variables)
    print("Removing variables")
    for remove_var in model_variables:
        score, feature_importance, _ = run([v for v in model_variables if v != remove_var], model=MODEL, reduce_features=False)
        scores.append(score)
        if score+.0001<best_score:
            print("Updating master list!")
            model_variables.remove(remove_var)
            #list(features_kept)
        if len(scores)>100:
            scores = scores[-100:]
        best_score=np.min(scores)

# %%
#model_variables = ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'LandContour_Low_orig_categ', 'BsmtUnfSF_cont_trans_normal', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'TotalSQF_cont_trans_normal', 'Heating_Wall_orig_categ', 'LotShape_Reg_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_Mitchel_orig_categ', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'Exterior1st_CemntBd_orig_categ', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'Heating_GasA_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofStyle_Gable_orig_categ', 'SaleCondition_Partial_orig_categ', 'Neighborhood_ClearCr_orig_categ', 'Foundation_Stone_orig_categ', 'RoofMatl_Membran_orig_categ', 'RoofMatl_Metal_orig_categ', 'MSSubClass_70_orig_categ', 'Functional_ord_trans_scale01', 'YrSold_2008_orig_categ', 'Neighborhood_CollgCr_orig_categ', 'LandContour_HLS_orig_categ', 'MiscVal_cont_trans_root', 'Fence_ord_trans_quadratic', 'Neighborhood_NPkVill_orig_categ', 'PoolQC_ord_trans_quadratic', '1stFlrSF_cont_trans_quadratic', 'LotConfig_FR3_orig_categ', 'BsmtQual_ord_trans_scale01', 'SaleCondition_Alloca_orig_categ', 'NewHouse_orig_categ', 'LotShape_IR1_orig_categ', 'Exterior2nd_AsbShng_orig_categ', 'Id', 'MSSubClass_20_orig_categ', 'Exterior2nd_HdBoard_orig_categ', 'ExterCond_ord_trans_scale01', 'HouseStyle_2Story_orig_categ', 'Exterior2nd_Brk Cmn_orig_categ', 'RoofStyle_Shed_orig_categ', 'FullBath_cont_trans_quadratic', 'HouseStyle_2.5Unf_orig_categ', 'Alley_Pave_orig_categ', 'RoofMatl_Tar&Grv_orig_categ', 'Exterior1st_CBlock_orig_categ', 'LotConfig_FR2_orig_categ', 'RoofStyle_Mansard_orig_categ', 'PoolArea_cont_trans_root', 'Condition2_RRAe_orig_categ', 'LandSlope_Gtl_orig_categ', 'MiscFeature_Othr_orig_categ', 'MSSubClass_80_orig_categ', 'Fireplaces_cont_trans_normal', 'RoofStyle_Hip_orig_categ', 'Exterior1st_WdShing_orig_categ', 'Condition2_Feedr_orig_categ', 'MiscFeature_Shed_orig_categ', 'Neighborhood_Blmngtn_orig_categ', 'RoofMatl_WdShngl_orig_categ', 'Electrical_SBrkr_orig_categ', 'Exterior1st_Wd Sdng_orig_categ', 'BldgType_Twnhs_orig_categ', 'MSSubClass_45_orig_categ', 'BsmtFinSF1_cont_trans_normal', 'EnclosedPorch_cont_trans_quadratic', 'LotConfig_Corner_orig_categ', 'GarageType_CarPort_orig_categ', 'KitchenQual_ord_trans_scale01', 'SaleType_ConLI_orig_categ', 'Foundation_BrkTil_orig_categ', 'Foundation_PConc_orig_categ', 'Exterior2nd_Stucco_orig_categ', 'PrchSQ_cont_trans_quadratic', 'Exterior1st_Plywood_orig_categ', 'GarageType_0_orig_categ', 'MiscFeature_Gar2_orig_categ', 'BsmtFinType2_ord_trans_quadratic', 'Heating_GasW_orig_categ', 'SaleType_Oth_orig_categ', 'LotShape_IR3_orig_categ', 'Exterior2nd_VinylSd_orig_categ', 'SaleType_CWD_orig_categ', 'HouseStyle_SLvl_orig_categ', 'Exterior1st_Stucco_orig_categ', 'Condition2_Norm_orig_categ', 'Neighborhood_SWISU_orig_categ', 'MSSubClass_85_orig_categ', 'BldgType_TwnhsE_orig_categ', 'BldgType_Duplex_orig_categ', 'WoodDeckSF_cont_trans_scale01', 'GarageType_Attchd_orig_categ', 'MSSubClass_40_orig_categ', 'GarageAgeInv_cont_trans_normal', 'BsmtHalfBath_cont_trans_normal', 'Neighborhood_StoneBr_orig_categ', 'GarageType_Basment_orig_categ', 'MasVnrType_ord_trans_root', 'LandSlope_Mod_orig_categ', 'Condition1_RRNn_orig_categ', 'BsmtFinSF2_cont_trans_quadratic', 'Condition1_RRAn_orig_categ', 'MSSubClass_160_orig_categ', 'Neighborhood_SawyerW_orig_categ', 'RoofMatl_CompShg_orig_categ', 'Exterior1st_AsbShng_orig_categ', 'Condition2_RRAn_orig_categ', 'Exterior1st_HdBoard_orig_categ', 'LandSlope_Sev_orig_categ', 'MSSubClass_90_orig_categ', 'Neighborhood_Timber_orig_categ', 'Season_0_orig_categ', 'Exterior2nd_Wd Shng_orig_categ', 'Utilities_ord_trans_quadratic', 'OpenPorchSF_cont_trans_normal', 'Exterior2nd_Stone_orig_categ', 'MSSubClass_75_orig_categ', 'Exterior1st_AsphShn_orig_categ', 'MoSold_cont_trans_normal', 'Season_2_orig_categ', 'Heating_Grav_orig_categ', 'Electrical_FuseA_orig_categ', 'LowQualFinSF_cont_trans_root', 'KitchenAbvGr_cont_trans_root', 'Neighborhood_Somerst_orig_categ']
print(model_variables)
# Out:
# ['Heating_Floor_orig_categ', 'SaleType_Con_orig_categ', 'SaleType_COD_orig_categ', 'HouseStyle_2.5Fin_orig_categ', 'KitchenAbvGr_cont_trans_root', 'Condition1_RRAe_orig_categ', 'Neighborhood_Somerst_orig_categ', 'Electrical_Mix_orig_categ', 'Condition1_PosA_orig_categ', 'CentralAir_ord_trans_inverse', 'SQFperRoom_cont_trans_quadratic', 'Exterior2nd_ImStucc_orig_categ', 'Neighborhood_Crawfor_orig_categ', 'GarageType_2Types_orig_categ', 'Street_Grvl_orig_categ', 'Season_3_orig_categ', 'Neighborhood_IDOTRR_orig_categ', 'BedroomAbvGr_cont_trans_normal', 'HouseStyle_1Story_orig_categ', 'Exterior2nd_Plywood_orig_categ', 'LandContour_Low_orig_categ', 'RoofStyle_Flat_orig_categ', 'GarageArea_cont_trans_scale01', 'FireplaceQu_ord_trans_log', 'MSZoning_FV_orig_categ', 'Electrical_FuseP_orig_categ', 'ScreenPorch_cont_trans_normal', 'OverallQual_cont_trans_root', 'Foundation_Slab_orig_categ', 'MSZoning_RH_orig_categ', 'SaleCondition_Family_orig_categ', 'Heating_Wall_orig_categ', 'LotShape_Reg_orig_categ', 'SaleCondition_Abnorml_orig_categ', 'GarageType_Detchd_orig_categ', 'HouseAge_cont_trans_normal', 'Neighborhood_Mitchel_orig_categ', 'Neighborhood_NWAmes_orig_categ', 'Neighborhood_Veenker_orig_categ', 'Neighborhood_Sawyer_orig_categ', 'Condition2_PosA_orig_categ', 'Neighborhood_Blueste_orig_categ', 'HasPool_orig_categ', 'Neighborhood_BrDale_orig_categ', 'YrSold_2007_orig_categ', 'RoofMatl_ClyTile_orig_categ', 'Neighborhood_MeadowV_orig_categ', 'Condition1_PosN_orig_categ', 'MSZoning_RL_orig_categ', 'Neighborhood_OldTown_orig_categ', 'MSSubClass_120_orig_categ', 'TotalBsmtSF_cont_trans_quadratic', 'ExterQual_ord_trans_scale01', 'Exterior1st_BrkFace_orig_categ', 'Street_Pave_orig_categ', 'BsmtExposure_ord_trans_quadratic', 'Exterior1st_Stone_orig_categ', 'YrSold_2006_orig_categ', 'Electrical_FuseF_orig_categ', 'BsmtFinType1_ord_trans_quadratic', 'MSSubClass_60_orig_categ', 'Exterior2nd_Wd Sdng_orig_categ', 'MSSubClass_180_orig_categ', 'Exterior2nd_CmentBd_orig_categ', 'Foundation_Wood_orig_categ', 'MasVnrArea_cont_trans_normal', 'Alley_Grvl_orig_categ', 'YrSold_2010_orig_categ', '2ndFlrSF_cont_trans_root', 'MSSubClass_30_orig_categ', 'BsmtFullBath_cont_trans_root', '3SsnPorch_cont_trans_quadratic', 'Exterior2nd_MetalSd_orig_categ', 'LotShape_IR2_orig_categ', 'SaleType_ConLD_orig_categ', 'Condition2_RRNn_orig_categ', 'Neighborhood_NridgHt_orig_categ', 'MSSubClass_50_orig_categ', 'SaleCondition_AdjLand_orig_categ', 'Condition1_Feedr_orig_categ', 'GarageIdx_cont_trans_root', 'Exterior1st_MetalSd_orig_categ', 'HouseStyle_SFoyer_orig_categ', 'Neighborhood_NAmes_orig_categ', 'Condition1_Artery_orig_categ', 'HeatingQC_ord_trans_normal', 'Exterior2nd_Other_orig_categ', 'HouseStyle_1.5Unf_orig_categ', 'RoofStyle_Gambrel_orig_categ', 'GrLivArea_cont_trans_log', 'RemodelAge_cont_trans_log', 'Season_1_orig_categ', 'BsmtCond_ord_trans_normal', 'Neighborhood_Edwards_orig_categ', 'GarageFinish_ord_trans_normal', 'Exterior1st_CemntBd_orig_categ', 'LandContour_Bnk_orig_categ', 'MSSubClass_190_orig_categ', 'Heating_GasA_orig_categ', 'LargeHouse_orig_categ', 'Exterior2nd_AsphShn_orig_categ', 'RoofMatl_Roll_orig_categ', 'PavedDrive_ord_trans_quadratic', 'Heating_OthW_orig_categ', 'Neighborhood_NoRidge_orig_categ', 'SummerSale_orig_categ', 'BldgType_2fmCon_orig_categ', 'RoofMatl_WdShake_orig_categ', 'Exterior1st_ImStucc_orig_categ', 'Foundation_CBlock_orig_categ', 'TotRmsAbvGrd_cont_trans_normal', 'Exterior1st_BrkComm_orig_categ', 'HouseStyle_1.5Fin_orig_categ', 'GarageType_BuiltIn_orig_categ', 'OverallCond_cont_trans_log', 'LotFrontage_cont_trans_quadratic', 'YrSold_2009_orig_categ', 'LotArea_cont_trans_log', 'BldgType_1Fam_orig_categ', 'GarageCond_ord_trans_quadratic', 'SaleType_ConLw_orig_categ', 'MiscFeature_TenC_orig_categ', 'Exterior1st_VinylSd_orig_categ', 'LandContour_Lvl_orig_categ', 'Exterior2nd_BrkFace_orig_categ', 'Exterior2nd_CBlock_orig_categ', 'Neighborhood_Gilbert_orig_categ', 'Condition2_Artery_orig_categ', 'SaleType_New_orig_categ', 'RoofSty ...

# %%
# Run one
#regression_list = master_keep_list[:]
ex_path = "/medic/github/housing-prices/output/ensemble.csv"

real_test_targets = test_targets[0:1459]
real_test_features = test_features[0:1459]

keep_variables = model_variables[:]
_, _, my_model = run(keep_variables, model="ElasticNetCV", feats=huge_variable_repository, test_feats=huge_variable_repository_test)
test_score = get_test_score(my_model, real_test_features[keep_variables], real_test_targets)
print("Real test score: {}".format(test_score))
prediction = my_model.predict(real_test_features[keep_variables])
export(ex_path, real_test_targets, prediction)
main.cv(my_model, huge_variable_repository[keep_variables], targets)

print(np.exp(prediction))
print(np.exp(test_targets))
# Out:
# Test score: 0.11255633481266816
# Test score: 0.11255633481266816
# Real test score: 0.11255633481266816
# CV score: 0.11358660429842679
# [119176.58130859 160426.06055485 181349.62145757 ... 163179.35877926
#  123093.50404946 222365.32506136]
# 0       105001.0
# 1       172001.0
# 2       189901.0
# 3       195501.0
# 4       191501.0
# 5       175901.0
# 6       185001.0
# 7       180401.0
# 8       171501.0
# 9       126001.0
#           ...
# 1449     73001.0
# 1450     79401.0
# 1451    140001.0
# 1452     87551.0
# 1453     79501.0
# 1454     90501.0
# 1455     71001.0
# 1456    131001.0
# 1457    132001.0
# 1458    188001.0
# Name: SalePrice, Length: 1459, dtype: float64

# %%
print(features.shape)
# Out:
# (1460, 7142)

# %%
import export_data

def export(path, test, prediction):
    ex_path = "/medic/github/housing-prices/output/ensemble.csv"
    prediction = np.exp(prediction)-1
    ids = np.array(range(1461,1461+test.shape[0]))
    submission_df = pd.concat([pd.Series(ids),pd.DataFrame(prediction, columns=["SalePrice"])], axis=1)
    submission_df.columns = ["Id", "SalePrice"]
    export_data.export_data(submission_df, path)

#export(ex_path, my_model.model, features.values)
#export(ex_path, my_model.model, test_features.values)
